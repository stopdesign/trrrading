# %%
import pytz
import pandas as pd
from pprint import pprint
from ib_insync import *
from ib_insync.ticker import TickerUpdateEvent
from datetime import datetime, timedelta, timezone
import pandas_market_calendars as mcal
from time import sleep

dt = datetime.now()
util.startLoop()

pd.options.display.width = 100

tz = pytz.timezone('America/New_York')

with IB() as ib:
    ib.connect("127.0.0.1", 4001, clientId=13)

    # f_con = Future("MES", exchange="GLOBEX", localSymbol="MESZ1")
    # f_con = ContFuture("MES", exchange="GLOBEX")
    f_con = ContFuture("MYM", exchange="ECBOT")
    # f_con = Stock("URA", exchange="ARCA")
    ib.qualifyContracts(f_con)
    print("multiplier =", f_con.multiplier)
    print()

    f_con.secType
    f_con.multiplier

    det = ib.reqContractDetails(f_con)[0]

    det.minTick
    det.longName

    print(str(det).replace(", ", "\n"))


    print("positions")
    for pos in ib.portfolio():
        con = pos.contract
        pprint(pos)
        sleep(1)
        ib.qualifyContracts(con)
        sleep(1)
        pprint(pos)
    print()

    print("====")
# Out:
# multiplier = 0.5
#
# ContractDetails(contract=Contract(secType='CONTFUT'
# conId=477836934
# symbol='MYM'
# lastTradeDateOrContractMonth='20220318'
# multiplier='0.5'
# exchange='ECBOT'
# currency='USD'
# localSymbol='MYM  MAR 22'
# tradingClass='MYM')
# marketName='MYM'
# minTick=1.0
# orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF'
# validExchanges='ECBOT'
# priceMagnifier=1
# underConId=362688015
# longName='Micro E-Mini Dow Jones Industrial Average Index'
# contractMonth='202203'
# industry=''
# category=''
# subcategory=''
# timeZoneId='US/Central'
# tradingHours='20211213:1700-20211214:1600;20211214:1700-20211215:1600;20211215:1700-20211216:1600;20211216:1700-20211217:1600;20211218:CLOSED;20211219:1700-20211220:1600'
# liquidHours='20211214:0830-20211214:1600;20211215:0830-20211215:1600;20211216:0830-20211216:1600;20211217:0830-20211217:1600;20211218:CLOSED;20211219:1700-20211220:1600'
# evRule=''
# evMultiplier=0
# mdSizeMultiplier=1
# aggGroup=2147483647
# underSymbol='MYM'
# underSecType='IND'
# marketRuleIds='68'
# secIdList=[]
# realExpirationDate='20220318'
# lastTradeTime='08:30'
# stockType=''
# cusip=''
# ratings=''
# descAppend=''
# bondType=''
# couponType=''
# callable=False
# putable=False
# coupon=0
# convertible=False
# maturity=''
# issueDate=''
# nextOptionDate=''
# nextOptionType=''
# nextOptionPartial=False
# notes='')
# positions
# PortfolioItem(contract=Future(conId=446091427, symbol='MES', lastTradeDateOrContractMonth='20211217', right='0', multiplier='5', primaryExchange='GLOBEX', currency='USD', localSymbol='MESZ1', tradingClass='MES'), position=28.0, marketPrice=4646.25, marketValue=650475.0, averageCost=23219.7557143, unrealizedPNL=321.84, realizedPNL=28.06, account='DU1492107')
# PortfolioItem(contract=Future(conId=446091427, symbol='MES', lastTradeDateOrContractMonth='20211217', multiplier='5', exchange='GLOBEX', currency='USD', localSymbol='MESZ1', tradingClass='MES'), position=28.0, marketPrice=4646.25, marketValue=650475.0, averageCost=23219.7557143, unrealizedPNL=321.84, realizedPNL=28.06, account='DU1492107')
# PortfolioItem(contract=Future(conId=446091522, symbol='MNQ', lastTradeDateOrContractMonth='20211217', right='0', multiplier='2', primaryExchange='GLOBEX', currency='USD', localSymbol='MNQZ1', tradingClass='MNQ'), position=8.0, marketPrice=15964.71777345, marketValue=255435.48, averageCost=31939.47, unrealizedPNL=-80.28, realizedPNL=-231.52, account='DU1492107')
# PortfolioItem(contract=Future(conId=446091522, symbol='MNQ', lastTradeDateOrContractMonth='20211217', multiplier='2', exchange='GLOBEX', currency='USD', localSymbol='MNQZ1', tradingClass='MNQ'), position=8.0, marketPrice=15964.71777345, marketValue=255435.48, averageCost=31939.47, unrealizedPNL=-80.28, realizedPNL=-231.52, account='DU1492107')
# PortfolioItem(contract=Future(conId=461318776, symbol='MYM', lastTradeDateOrContractMonth='20211217', right='0', multiplier='0.5', primaryExchange='ECBOT', currency='USD', localSymbol='MYM  DEC 21', tradingClass='MYM'), position=3.0, marketPrice=35617.953125, marketValue=53426.93, averageCost=17807.97, unrealizedPNL=3.02, realizedPNL=-39.7, account='DU1492107')
# PortfolioItem(contract=Future(conId=461318776, symbol='MYM', lastTradeDateOrContractMonth='20211217', multiplier='0.5', exchange='ECBOT', currency='USD', localSymbol='MYM  DEC 21', tradingClass='MYM'), position=3.0, marketPrice=35617.953125, marketValue=53426.93, averageCost=17807.97, unrealizedPNL=3.02, realizedPNL=-39.7, account='DU1492107')
#
# ====
