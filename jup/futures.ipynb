# %%
import pytz
import pandas as pd
from pprint import pprint
from ib_insync import *
from ib_insync.ticker import TickerUpdateEvent
from datetime import datetime, timedelta, timezone
import pandas_market_calendars as mcal
from time import sleep

dt = datetime.now()
util.startLoop()

pd.options.display.width = 100

tz = pytz.timezone('America/New_York')

with IB() as ib:
    ib.connect("127.0.0.1", 4001, clientId=13)

    # f_con = Future("MES", exchange="GLOBEX", localSymbol="MESZ1")
    f_con = ContFuture("MES", exchange="GLOBEX")
    ib.qualifyContracts(f_con)
    print(f_con)
    print()

    print("positions")
    for pos in ib.portfolio():
        con = pos.contract
        pprint(pos)
        sleep(1)
        ib.qualifyContracts(con)
        sleep(1)
        pprint(pos)
    print()

    print("====")
# Out:
# ContFuture(conId=446091427, symbol='MES', lastTradeDateOrContractMonth='20211217', multiplier='5', exchange='GLOBEX', currency='USD', localSymbol='MESZ1', tradingClass='MES')
#
# positions
#
# ====
